# %%
#loading the data
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\top_anime_dataset.csv")

# %%
df.head()
# Out:
#    mal_id                             title  \
# 0   52991                 Sousou no Frieren
# 1   59978      Sousou no Frieren 2nd Season
# 2    5114  Fullmetal Alchemist: Brotherhood
# 3   57555      Chainsaw Man Movie: Reze-hen
# 4    9253                       Steins;Gate
#
#                             title_english   type        source  episodes  \
# 0           Frieren: Beyond Journey's End     TV         Manga      28.0
# 1  Frieren: Beyond Journey's End Season 2     TV         Manga      10.0
# 2        Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3      Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# 4                             Steins;Gate     TV  Visual novel      24.0
#
#              status  airing                          rating  score  scored_by  \
# 0   Finished Airing   False       PG-13 - Teens 13 or older   9.28     823434
# 1  Currently Airing    True       PG-13 - Teens 13 or older   9.16      62148
# ...

# %%
print(df.tail())
# Out:
#      mal_id                          title                   title_english  \
# 495   32867   Bungou Stray Dogs 2nd Season              Bungo Stray Dogs 2
# 496   33674          No Game No Life: Zero          No Game, No Life: Zero
# 497     962               Aria the Natural                Aria the Natural
# 498     853         Ouran Koukou Host Club     Ouran High School Host Club
# 499    1889  Higurashi no Naku Koro ni Kai  Higurashi: When They Cry – Kai
#
#       type        source  episodes           status  airing  \
# 495     TV         Manga      12.0  Finished Airing   False
# 496  Movie   Light novel       1.0  Finished Airing   False
# 497     TV         Manga      26.0  Finished Airing   False
# 498     TV         Manga      26.0  Finished Airing   False
# 499     TV  Visual novel      24.0  Finished Airing   False
#
#                              rating  score  ...   rank  popularity  members  \
# ...

# %%
print(df.shape)
# Out:
# (500, 21)

# %%
print(df.dtypes)
# Out:
# mal_id             int64
# title             object
# title_english     object
# type              object
# source            object
# episodes         float64
# status            object
# airing              bool
# rating            object
# score            float64
# scored_by          int64
# rank             float64
# popularity         int64
# members            int64
# favorites          int64
# synopsis          object
# year             float64
# genres            object
# studios           object
# url               object
# Episodes           int64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mal_id         500 non-null    int64
#  1   title          500 non-null    object
#  2   title_english  458 non-null    object
#  3   type           500 non-null    object
#  4   source         500 non-null    object
#  5   episodes       492 non-null    float64
#  6   status         500 non-null    object
#  7   airing         500 non-null    bool
#  8   rating         500 non-null    object
#  9   score          500 non-null    float64
#  10  scored_by      500 non-null    int64
#  11  rank           492 non-null    float64
#  12  popularity     500 non-null    int64
#  13  members        500 non-null    int64
#  14  favorites      500 non-null    int64
#  15  synopsis       500 non-null    object
#  16  year           297 non-null    float64
# ...

# %%
print(df.describe())
# Out:
#              mal_id    episodes       score     scored_by        rank  \
# count    500.000000  492.000000  500.000000  5.000000e+02  492.000000
# mean   30996.616000   18.357724    8.428940  3.271719e+05  246.552846
# std    20276.672967   35.417988    0.222604  4.517006e+05  142.217810
# min        1.000000    1.000000    8.160000  9.190000e+02    1.000000
# 25%    10143.250000    1.000000    8.250000  4.857050e+04  123.750000
# 50%    35847.000000   12.000000    8.370000  1.519620e+05  246.500000
# 75%    49393.500000   24.000000    8.562500  4.098580e+05  369.250000
# max    63019.000000  500.000000    9.280000  3.038808e+06  494.000000
#
#          popularity       members      favorites         year     Episodes
# count    500.000000  5.000000e+02     500.000000   297.000000   500.000000
# mean    1559.430000  5.789175e+05   13815.252000  2015.070707     4.022000
# std     1919.380637  6.924760e+05   29497.765969     9.007038    89.934654
# ...

# %%
print(df.isnull().sum())
# Out:
# mal_id             0
# title              0
# title_english     42
# type               0
# source             0
# episodes           8
# status             0
# airing             0
# rating             0
# score              0
# scored_by          0
# rank               8
# popularity         0
# members            0
# favorites          0
# synopsis           0
# year             203
# genres             6
# studios            2
# url                0
# Episodes           0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
clean_df = df.dropna()
df
# Out:
#      mal_id                             title  \
# 0     52991                 Sousou no Frieren
# 1     59978      Sousou no Frieren 2nd Season
# 2      5114  Fullmetal Alchemist: Brotherhood
# 3     57555      Chainsaw Man Movie: Reze-hen
# 4      9253                       Steins;Gate
# ..      ...                               ...
# 495   32867      Bungou Stray Dogs 2nd Season
# 496   33674             No Game No Life: Zero
# 497     962                  Aria the Natural
# 498     853            Ouran Koukou Host Club
# 499    1889     Higurashi no Naku Koro ni Kai
#
#                               title_english   type        source  episodes  \
# 0             Frieren: Beyond Journey's End     TV         Manga      28.0
# 1    Frieren: Beyond Journey's End Season 2     TV         Manga      10.0
# 2          Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3        Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# ...

# %%
df[df['score'] > 9]
df
# Out:
#      mal_id                             title  \
# 0     52991                 Sousou no Frieren
# 1     59978      Sousou no Frieren 2nd Season
# 2      5114  Fullmetal Alchemist: Brotherhood
# 3     57555      Chainsaw Man Movie: Reze-hen
# 4      9253                       Steins;Gate
# ..      ...                               ...
# 495   32867      Bungou Stray Dogs 2nd Season
# 496   33674             No Game No Life: Zero
# 497     962                  Aria the Natural
# 498     853            Ouran Koukou Host Club
# 499    1889     Higurashi no Naku Koro ni Kai
#
#                               title_english   type        source  episodes  \
# 0             Frieren: Beyond Journey's End     TV         Manga      28.0
# 1    Frieren: Beyond Journey's End Season 2     TV         Manga      10.0
# 2          Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3        Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# ...

# %%
df[df['episodes'] > 50]
# Out:
#      mal_id                                    title  \
# 2      5114         Fullmetal Alchemist: Brotherhood
# 6     28977                                 Gintama°
# 8     11061                   Hunter x Hunter (2011)
# 10     9969                                 Gintama'
# 12      820                     Ginga Eiyuu Densetsu
# 18      918                                  Gintama
# 24       19                                  Monster
# 40      263                           Hajime no Ippo
# 131   60557         Fanren Xiu Xian Zhuan 4th Season
# 139     170                                Slam Dunk
# 172   12431                            Uchuu Kyoudai
# 185     392                          Yuu☆Yuu☆Hakusho
# 201     136                          Hunter x Hunter
# 202   51039                Doupo Cangqiong: Nian Fan
# 218   33255                     Saiki Kusuo no Ψ-nan
# 245   56524               Tunshi Xingkong 4th Season
# 257    2402                            Ashita no Joe
# ...

# %%
df[df['type'] == 'TV']
# Out:
#      mal_id                               title  \
# 0     52991                   Sousou no Frieren
# 1     59978        Sousou no Frieren 2nd Season
# 2      5114    Fullmetal Alchemist: Brotherhood
# 4      9253                         Steins;Gate
# 5     38524  Shingeki no Kyojin Season 3 Part 2
# ..      ...                                 ...
# 494   57181                          Ao no Hako
# 495   32867        Bungou Stray Dogs 2nd Season
# 497     962                    Aria the Natural
# 498     853              Ouran Koukou Host Club
# 499    1889       Higurashi no Naku Koro ni Kai
#
#                               title_english type        source  episodes  \
# 0             Frieren: Beyond Journey's End   TV         Manga      28.0
# 1    Frieren: Beyond Journey's End Season 2   TV         Manga      10.0
# 2          Fullmetal Alchemist: Brotherhood   TV         Manga      64.0
# 4                               Steins;Gate   TV  Visual novel      24.0
# ...

# %%
df[df['status'] == 'Finished Airing']
# Out:
#      mal_id                               title  \
# 0     52991                   Sousou no Frieren
# 2      5114    Fullmetal Alchemist: Brotherhood
# 3     57555        Chainsaw Man Movie: Reze-hen
# 4      9253                         Steins;Gate
# 5     38524  Shingeki no Kyojin Season 3 Part 2
# ..      ...                                 ...
# 495   32867        Bungou Stray Dogs 2nd Season
# 496   33674               No Game No Life: Zero
# 497     962                    Aria the Natural
# 498     853              Ouran Koukou Host Club
# 499    1889       Higurashi no Naku Koro ni Kai
#
#                           title_english   type        source  episodes  \
# 0         Frieren: Beyond Journey's End     TV         Manga      28.0
# 2      Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3    Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# 4                           Steins;Gate     TV  Visual novel      24.0
# ...

# %%
df.sort_values('score', ascending=False)
# Out:
#      mal_id                             title  \
# 0     52991                 Sousou no Frieren
# 1     59978      Sousou no Frieren 2nd Season
# 2      5114  Fullmetal Alchemist: Brotherhood
# 3     57555      Chainsaw Man Movie: Reze-hen
# 4      9253                       Steins;Gate
# ..      ...                               ...
# 495   32867      Bungou Stray Dogs 2nd Season
# 496   33674             No Game No Life: Zero
# 497     962                  Aria the Natural
# 498     853            Ouran Koukou Host Club
# 499    1889     Higurashi no Naku Koro ni Kai
#
#                               title_english   type        source  episodes  \
# 0             Frieren: Beyond Journey's End     TV         Manga      28.0
# 1    Frieren: Beyond Journey's End Season 2     TV         Manga      10.0
# 2          Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3        Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# ...

# %%
df.sort_values('popularity')
# Out:
#      mal_id                                  title  \
# 122   16498                     Shingeki no Kyojin
# 98     1535                             Death Note
# 2      5114       Fullmetal Alchemist: Brotherhood
# 173   30276                          One Punch Man
# 223   38000                       Kimetsu no Yaiba
# ..      ...                                    ...
# 235   56523             Tunshi Xingkong 3rd Season
# 402   56215           Yi Nian Yong Heng 3rd Season
# 266   57067  Fanren Xiu Xian Zhuan: Xinghai Feichi
# 131   60557       Fanren Xiu Xian Zhuan 4th Season
# 446   60420                         Cang Yuan Tu 2
#
#                                          title_english type     source  \
# 122                                    Attack on Titan   TV      Manga
# 98                                          Death Note   TV      Manga
# 2                     Fullmetal Alchemist: Brotherhood   TV      Manga
# ...

# %%
df.groupby('type')['score'].mean()
# Out:
# type
# Movie         8.410877
# Music         8.397143
# ONA           8.415455
# OVA           8.358235
# PV            8.380000
# Special       8.336667
# TV            8.443401
# TV Special    8.489091
# Name: score, dtype: float64

# %%
df.groupby('status').size()
# Out:
# status
# Currently Airing     20
# Finished Airing     480
# dtype: int64

# %%
df.groupby('source')['score'].max()
# Out:
# source
# 4-koma manga    8.73
# Book            8.28
# Game            8.64
# Light novel     9.02
# Manga           9.28
# Mixed media     8.22
# Music           8.62
# Novel           9.02
# Original        8.91
# Other           8.39
# Visual novel    9.07
# Web manga       8.78
# Web novel       8.67
# Name: score, dtype: float64

# %%
df['type'].value_counts()
# Out:
# type
# TV            297
# Movie         114
# ONA            44
# OVA            17
# TV Special     11
# Special         9
# Music           7
# PV              1
# Name: count, dtype: int64

# %%
df['source'].value_counts()
# Out:
# source
# Manga           280
# Original         68
# Light novel      54
# Web novel        25
# Novel            23
# Web manga        20
# Visual novel     13
# Game              6
# 4-koma manga      4
# Other             4
# Music             1
# Book              1
# Mixed media       1
# Name: count, dtype: int64

# %%
def pop(x):
    if x < 100:
        return "Very Popular"
    elif x < 500:
        return "Popular"
    else:
        return "Normal"

df['pop_category'] = df['popularity'].apply(pop)
df
# Out:
#      mal_id                             title  \
# 0     52991                 Sousou no Frieren
# 1     59978      Sousou no Frieren 2nd Season
# 2      5114  Fullmetal Alchemist: Brotherhood
# 3     57555      Chainsaw Man Movie: Reze-hen
# 4      9253                       Steins;Gate
# ..      ...                               ...
# 495   32867      Bungou Stray Dogs 2nd Season
# 496   33674             No Game No Life: Zero
# 497     962                  Aria the Natural
# 498     853            Ouran Koukou Host Club
# 499    1889     Higurashi no Naku Koro ni Kai
#
#                               title_english   type        source  episodes  \
# 0             Frieren: Beyond Journey's End     TV         Manga      28.0
# 1    Frieren: Beyond Journey's End Season 2     TV         Manga      10.0
# 2          Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3        Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# ...

# %%
df['title'].str.upper()
# Out:
# 0                     SOUSOU NO FRIEREN
# 1          SOUSOU NO FRIEREN 2ND SEASON
# 2      FULLMETAL ALCHEMIST: BROTHERHOOD
# 3          CHAINSAW MAN MOVIE: REZE-HEN
# 4                           STEINS;GATE
#                      ...
# 495        BUNGOU STRAY DOGS 2ND SEASON
# 496               NO GAME NO LIFE: ZERO
# 497                    ARIA THE NATURAL
# 498              OURAN KOUKOU HOST CLUB
# 499       HIGURASHI NO NAKU KORO NI KAI
# Name: title, Length: 500, dtype: object

# %%
df['title'].apply(len)
# Out:
# 0      17
# 1      28
# 2      32
# 3      28
# 4      11
#        ..
# 495    28
# 496    21
# 497    16
# 498    22
# 499    29
# Name: title, Length: 500, dtype: int64

# %%
df[df['title'].str.contains('Naruto', na=False)]
# Out:
#      mal_id               title     title_english type source  episodes  \
# 236   53236      Road of Naruto    Road of Naruto   PV  Manga       1.0
# 337    1735  Naruto: Shippuuden  Naruto Shippuden   TV  Manga     500.0
#
#               status  airing                     rating  score  ...  \
# 236  Finished Airing   False  PG-13 - Teens 13 or older   8.38  ...
# 337  Finished Airing   False  PG-13 - Teens 13 or older   8.29  ...
#
#      popularity  members  favorites  \
# 236        4078    38856        112
# 337          15  2721147     119705
#
#                                               synopsis    year  \
# 236  In celebration of 20 years of Naruto, Studio P...     NaN
# 337  It has been two and a half years since Naruto ...  2007.0
#
#                          genres         studios  \
# 236             Action, Fantasy  Studio Pierrot
# 337  Action, Adventure, Fantasy  Studio Pierrot
#
#                                                    url Episodes  pop_category
# ...

# %%
df['score'].mean()
# Out:
# np.float64(8.428939999999999)

# %%
df['episodes'].max()
# Out:
# np.float64(500.0)

# %%
df['members'].sum()
# Out:
# np.int64(289458758)

# %%
df.nlargest(10, 'score')
# Out:
#    mal_id                               title  \
# 0   52991                   Sousou no Frieren
# 1   59978        Sousou no Frieren 2nd Season
# 2    5114    Fullmetal Alchemist: Brotherhood
# 3   57555        Chainsaw Man Movie: Reze-hen
# 4    9253                         Steins;Gate
# 5   38524  Shingeki no Kyojin Season 3 Part 2
# 6   28977                            Gintama°
# 7   39486                  Gintama: The Final
# 8   11061              Hunter x Hunter (2011)
# 9   60022                One Piece Fan Letter
#
#                             title_english        type        source  episodes  \
# 0           Frieren: Beyond Journey's End          TV         Manga      28.0
# 1  Frieren: Beyond Journey's End Season 2          TV         Manga      10.0
# 2        Fullmetal Alchemist: Brotherhood          TV         Manga      64.0
# 3      Chainsaw Man – The Movie: Reze Arc       Movie         Manga       1.0
# ...

# %%
df.loc[df.groupby('type')['score'].idxmax()]
# Out:
#      mal_id                         title                       title_english  \
# 3     57555  Chainsaw Man Movie: Reze-hen  Chainsaw Man – The Movie: Reze Arc
# 62    55016                          Idol                                 NaN
# 44    60489             Takopii no Genzai               Takopi's Original Sin
# 12      820          Ginga Eiyuu Densetsu       Legend of the Galactic Heroes
# 236   53236                Road of Naruto                      Road of Naruto
# 191   44087       Gintama: The Semi-Final                                 NaN
# 0     52991             Sousou no Frieren       Frieren: Beyond Journey's End
# 9     60022          One Piece Fan Letter                                 NaN
#
#            type       source  episodes           status  airing  \
# 3         Movie        Manga       1.0  Finished Airing   False
# 62        Music     Original       1.0  Finished Airing   False
# 44          ONA        Manga       6.0  Finished Airing   False
# ...

# %%
df[['episodes','score']].corr()
# Out:
#           episodes     score
# episodes  1.000000  0.044068
# score     0.044068  1.000000

# %%
df.sort_values('favorites', ascending=False).head(1)
# Out:
#     mal_id      title title_english type source  episodes            status  \
# 51      21  One Piece     One Piece   TV  Manga       NaN  Currently Airing
#
#     airing                     rating  score  ...  popularity  members  \
# 51    True  PG-13 - Teens 13 or older   8.73  ...          17  2643713
#
#     favorites                                           synopsis    year  \
# 51     249284  Barely surviving in a barrel after passing thr...  1999.0
#
#                         genres         studios  \
# 51  Action, Adventure, Fantasy  Toei Animation
#
#                                            url Episodes  pop_category
# 51  https://myanimelist.net/anime/21/One_Piece        0  Very Popular
#
# [1 rows x 22 columns]
