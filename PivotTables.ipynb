# %%
import numpy as np
import pandas as pd

# %%
print("Pivot Tables")
# Out:
# Pivot Tables

# %%
# Pivot Tables

data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South',
               'East', 'West', 'North', 'South',
               'East', 'West', 'North', 'South',
               'East', 'West', 'North', 'South',
               'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    135     83   John  January      Q1
# 1  2023-01-02       B   West    542     25   Mary  January      Q1
# 2  2023-01-03       C  North    390     29    Bob  January      Q1
# 3  2023-01-04       D  South    222     33  Alice  January      Q1
# 4  2023-01-05       A   East    829     66   John  January      Q1
# 5  2023-01-06       B   West    129     33   Mary  January      Q1
# 6  2023-01-07       C  North    376     11    Bob  January      Q1
# 7  2023-01-08       D  South    770     93  Alice  January      Q1
# 8  2023-01-09       A   East    783     64   John  January      Q1
# 9  2023-01-10       B   West    188     58   Mary  January      Q1
# 10 2023-01-11       C  North    870     91    Bob  January      Q1
# 11 2023-01-12       D  South    911     95  Alice  January      Q1
# 12 2023-01-13       A   East    978     25   John  January      Q1
# 13 2023-01-14       B   West    147     13   Mary  January      Q1
# 14 2023-01-15       C  North    104     88    Bob  January      Q1
# 15 2023-01-16       D  South    158     54  Alice  January      Q1
# 16 2023-01-17       A   East    731     38   John  January      Q1
# 17 2023-01-18       B   West    994     80   Mary  January      Q1
# 18 2023-01-19       C  North    375     51    Bob  January      Q1
# 19 2023-01-20       D  South    352     63  Alice  January      Q1

# %%
pd.pivot_table(df, values="Sales", index='Region', columns="Product", aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     783.0    NaN    NaN    NaN
# North      NaN    NaN  376.0    NaN
# South      NaN    NaN    NaN  352.0
# West       NaN  188.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     691.2    NaN    NaN    NaN  55.2   NaN   NaN   NaN
# North      NaN    NaN  423.0    NaN   NaN   NaN  54.0   NaN
# South      NaN    NaN    NaN  482.6   NaN   NaN   NaN  67.6
# West       NaN  400.0    NaN    NaN   NaN  41.8   NaN   NaN

# %%
print("Cross Tabs")
# Out:
# Cross Tabs

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
