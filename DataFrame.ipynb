# %%
import numpy as np
import pandas as pd

# %%
print("Creating a DataFrame")
# Out:
# Creating a DataFrame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [165000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  165000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 165000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  165000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#        0   1         2       3
# 0   John  28  New York  165000
# 1   Anna  34     Paris   70000
# 2  Peter  29    Berlin   62000
# 3  Linda  42    London   85000

# %%
print("Selection and Indexing of Column")
# Out:
# Selection and Indexing of Column

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  165000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[['Name', 'City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
print("Creating a New Column")
# Out:
# Creating a New Column

# %%
df2["Designation"] = ["Eng", "Doct", "Eng", "Doct"]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York  165000         Eng
# 1   Anna   34     Paris   70000        Doct
# 2  Peter   29    Berlin   62000         Eng
# 3  Linda   42    London   85000        Doct

# %%
print("Removing a Column")
# Out:
# Removing a Column

# %%
df2.drop('Designation', axis = 1, inplace = True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  165000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
print("Selecting Rows")
# Out:
# Selecting Rows

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  165000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0, 1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York  165000
# 1  Anna   34     Paris   70000

# %%
print("Selecting Subsets of Rows and Columns")
# Out:
# Selecting Subsets of Rows and Columns

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  165000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0, 1]][["City", "Salary"]]
# Out:
#        City  Salary
# 0  New York  165000
# 1     Paris   70000

# %%
df2.loc[[2, 3]][["Name", "Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %%
print("Conditional Selection")
# Out:
# Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  165000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[df2['Age'] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df2[(df2['Age'] > 30) & (df2['City'] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
